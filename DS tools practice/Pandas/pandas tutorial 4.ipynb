# %% [markdown]
# # Updating and renaming rows and columns

# %%
import pandas as pd
import matplotlib.pyplot as plt
people = {'first': ['Corey', 'Jane', 'John'],
          "last": ['Schafer', 'Doe', 'Doe'],
          "email": ['CoreyMSchafer@gmail.com', 'JaneMyass@mail.com', 'NoShitBob@gmail.com']}

df = pd.DataFrame(people)
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe       JaneMyass@mail.com
# 2   John      Doe      NoShitBob@gmail.com

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df.columns=['first_name','last_name','email']
df.columns
# Out:
# Index(['first_name', 'last_name', 'email'], dtype='object')

# %%
df.columns=[x.upper() for x in df.columns]
df
# Out:
#   FIRST_NAME LAST_NAME                    EMAIL
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe       JaneMyass@mail.com
# 2       John       Doe      NoShitBob@gmail.com

# %%
df.columns = df.columns.str.replace(' ', '_') # replacing spaces with underscore
df
# Out:
#   FIRST_NAME LAST_NAME                    EMAIL
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe       JaneMyass@mail.com
# 2       John       Doe      NoShitBob@gmail.com

# %%
df.rename(columns={'FIRST_NAME':'first','LAST_NAME':'last','EMAIL':'email'},inplace=True)
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe       JaneMyass@mail.com
# 2   John      Doe      NoShitBob@gmail.com

# %%
df.loc[2]=['John','Smith','JohnSmith@mail.com']
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe       JaneMyass@mail.com
# 2   John    Smith       JohnSmith@mail.com

# %%
df.loc[2,['last','email']] # we can pass second list as a columns that we want
# Out:
# last                  Smith
# email    JohnSmith@mail.com
# Name: 2, dtype: object

# %%
df.loc[2,['last','email']]=['Doe','JohnDoe@email.com']
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe       JaneMyass@mail.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.loc[2,'last']='Smith'
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe       JaneMyass@mail.com
# 2   John    Smith        JohnDoe@email.com

# %%
df.at[2,'last']='Doe' #we can use .at to change single values/ Tho we dont have to. we can use .loc

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe       JaneMyass@mail.com
# 2   John      Doe        JohnDoe@email.com

# %%
filt=(df['email']=='JohnDoe@email.com')
df[filt]['last']='Smith' # this WONT change value. BAD PRACTICE
# Out:
# C:\Users\Mi\AppData\Local\Temp\ipykernel_26072\2828147784.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[filt]['last']='Smith' # this WONT change value. BAD PRACTICE

# %%
# Best practice
df.loc[filt,'last']='Smith'
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe       JaneMyass@mail.com
# 2   John    Smith        JohnDoe@email.com

# %%
df['email']=df['email'].str.lower() # make lowercase from col
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  coreymschafer@gmail.com
# 1   Jane      Doe       janemyass@mail.com
# 2   John    Smith        johndoe@email.com

# %% [markdown]
# # Data transformation

# %%
"""
apply  -- apply function to each column
map
applymap
replace
"""
# Out:
# '\napply  -- apply values to each column\nmap\napplymap\nreplace\n'

# %%
# if we want to know length to each column
df['email'].apply(len)
# Out:
# 0    23
# 1    18
# 2    17
# Name: email, dtype: int64

# %%
def update_email(email):
    return email.upper()

# %%
df['email']=df['email'].apply(update_email) # we used function to update results of function
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  COREYMSCHAFER@GMAIL.COM
# 1   Jane      Doe       JANEMYASS@MAIL.COM
# 2   John    Smith        JOHNDOE@EMAIL.COM

# %%
df['email']=df['email'].apply(lambda x: x.lower())
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  coreymschafer@gmail.com
# 1   Jane      Doe       janemyass@mail.com
# 2   John    Smith        johndoe@email.com

# %%
df['email'].apply(len)
# Out:
# 0    23
# 1    18
# 2    17
# Name: email, dtype: int64

# %%
df.apply(len)
# Out:
# first    3
# last     3
# email    3
# dtype: int64

# %%
df.apply(len,axis='columns')
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
df.apply(pd.Series.min)
# Out:
# first                      Corey
# last                         Doe
# email    coreymschafer@gmail.com
# dtype: object

# %%
df.apply(lambda x: x.min())
# Out:
# first                      Corey
# last                         Doe
# email    coreymschafer@gmail.com
# dtype: object

# %%
df.applymap(len)
# Out:
#    first  last  email
# 0      5     7     23
# 1      4     3     18
# 2      4     5     17

# %%
df.applymap(str.upper)
# Out:
#    first     last                    email
# 0  COREY  SCHAFER  COREYMSCHAFER@GMAIL.COM
# 1   JANE      DOE       JANEMYASS@MAIL.COM
# 2   JOHN    SMITH        JOHNDOE@EMAIL.COM

# %%
df['first'].map({'Corey':'Chris','Jane':'Mary'})
# Out:
# 0    Chris
# 1     Mary
# 2      NaN
# Name: first, dtype: object

# %%
df['first']=df['first'].replace({'Corey':'Chris','Jane':'Mary'})

# %%
df['first']
# Out:
# 0    Chris
# 1     Mary
# 2     John
# Name: first, dtype: object

# %%
df_survey = pd.read_csv('data/survey_results_public.csv',index_col='Respondent')
schema_df = pd.read_csv('data/survey_results_schema.csv',index_col='Column')
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df_survey.rename(columns={'ConvertedComp':"SalaryUSD"},inplace=True)

# %%
df_survey['Hobbyist'].map({'Yes':True,'No':False})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 88377     True
# 88601    False
# 88802    False
# 88816    False
# 88863     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %%
df_survey.loc[(df_survey['Hobbyist']=="Yes")]
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 3           I am not primarily a developer, but I write co...      Yes
# 5                              I am a developer by profession      Yes
# 6           I am not primarily a developer, but I write co...      Yes
# 8                                 I code primarily as a hobby      Yes
# ...                                                       ...      ...
# 87739                                                     NaN      Yes
# 88182                                                     NaN      Yes
# 88282                                                     NaN      Yes
# 88377                                                     NaN      Yes
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 1                                                       Never
# 3                                                       Never
# 5                                  Once a month or more often
# 6                                                       Never
# 8                                     Less than once per year
# ...                                                       ...
# 87739                                 Less than once per year
# 88182                              Once a month or more often
# 88282                              Once a month or more often
# 88377       Less than once a month but more than once per ...
# 88863                                 Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# 5           OSS is, on average, of HIGHER quality than pro...
# 6           The quality of OSS and closed source software ...
# 8           OSS is, on average, of HIGHER quality than pro...
# ...                                                       ...
# 87739       OSS is, on average, of HIGHER quality than pro...
# 88182       OSS is, on average, of HIGHER quality than pro...
# 88282       The quality of OSS and closed source software ...
# 88377       The quality of OSS and closed source software ...
# 88863       OSS is, on average, of HIGHER quality than pro...
#
#                                         Employment         Country  \
# Respondent
# 1           Not employed, and not looking for work  United Kingdom
# 3                               Employed full-time        Thailand
# 5                               Employed full-time         Ukraine
# 6                               Employed full-time          Canada
# 8               Not employed, but looking for work           India
# ...                                            ...             ...
# 87739                           Employed part-time  Czech Republic
# 88182                           Employed part-time        Pakistan
# 88282           Not employed, but looking for work   United States
# 88377       Not employed, and not looking for work          Canada
# 88863       Not employed, and not looking for work           Spain
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# 3                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 6                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 8                      NaN           Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                    ...                                                ...
# 87739       Yes, full-time        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88182                  NaN  Secondary school (e.g. American high school, G...
# 88282                   No  Some college/university study without earning ...
# 88377                   No                          Primary/elementary school
# 88863       Yes, full-time                 Professional degree (JD, MD, etc.)
#
#                                                UndergradMajor  \
# Respondent
# 1                                                         NaN
# 3                               Web development or web design
# 5           Computer science, computer engineering, or sof...
# 6                                   Mathematics or statistics
# 8           Computer science, computer engineering, or sof...
# ...                                                       ...
# 87739       Computer science, computer engineering, or sof...
# 88182                                                     NaN
# 88282       Computer science, computer engineering, or sof...
# 88377                                                     NaN
# 88863       Computer science, computer engineering, or sof...
#
#                                                      EduOther  \
# Respondent
# 1           Taught yourself a new language, framework, or ...
# 3           Taught yourself a new language, framework, or ...
# 5           Taken an online course in programming or softw...
# 6           Taken an online course in programming or softw...
# 8           Taught yourself a new language, framework, or ...
# ...                                                       ...
# 87739       Taught yourself a new language, framework, or ...
# 88182       Taken an online course in programming or softw...
# 88282       Taught yourself a new language, framework, or ...
# 88377       Taught yourself a new language, framework, or ...
# 88863       Taken an online course in programming or softw...
#
#                              OrgSize  \
# Respondent
# 1                                NaN
# 3               100 to 499 employees
# 5           10,000 or more employees
# 6                                NaN
# 8                                NaN
# ...                              ...
# 87739           500 to 999 employees
# 88182             10 to 19 employees
# 88282                            NaN
# 88377                            NaN
# 88863                            NaN
#
#                                                       DevType YearsCode  \
# Respondent
# 1                                                         NaN         4
# 3           Designer;Developer, back-end;Developer, front-...         3
# 5           Academic researcher;Developer, desktop or ente...        16
# 6           Data or business analyst;Data scientist or mac...        13
# 8              Developer, back-end;Engineer, site reliability         8
# ...                                                       ...       ...
# 87739       Academic researcher;Designer;Developer, game o...         9
# 88182                                     Academic researcher         1
# 88282       Developer, back-end;Developer, desktop or ente...        38
# 88377                                                     NaN       NaN
# 88863                                                     NaN         8
#
#                       Age1stCode      YearsCodePro           CareerSat  \
# Respondent
# 1                             10               NaN                 NaN
# 3                             22                 1  Slightly satisfied
# 5                             14                 9   Very dissatisfied
# 6                             15                 3      Very satisfied
# 8                             16               NaN                 NaN
# ...                          ...               ...                 ...
# 87739                         16                 3                 NaN
# 88182       Younger than 5 years  Less than 1 year                 NaN
# 88282                         10                38                 NaN
# 88377                        NaN               NaN                 NaN
# 88863                         11                 3                 NaN
#
#                            JobSat              MgrIdiot  MgrMoney   MgrWant  \
# Respondent
# 1                             NaN                   NaN       NaN       NaN
# 3              Slightly satisfied  Not at all confident  Not sure  Not sure
# 5           Slightly dissatisfied    Somewhat confident       Yes        No
# 6              Slightly satisfied        Very confident        No       Yes
# 8                             NaN                   NaN       NaN       NaN
# ...                           ...                   ...       ...       ...
# 87739                         NaN    Somewhat confident        No  Not sure
# 88182                         NaN        Very confident  Not sure       Yes
# 88282                         NaN                   NaN       NaN       NaN
# 88377                         NaN                   NaN       NaN       NaN
# 88863                         NaN                   NaN       NaN       NaN
#
#                                                       JobSeek  \
# Respondent
# 1                                                         NaN
# 3           I’m not actively looking, but I am open to new...
# 5                I am not interested in new job opportunities
# 6                I am not interested in new job opportunities
# 8                                                         NaN
# ...                                                       ...
# 87739                                                     NaN
# 88182                                                     NaN
# 88282                                                     NaN
# 88377                                                     NaN
# 88863                                                     NaN
#
#                     LastHireDate  \
# Respondent
# 1                            NaN
# 3                  1-2 years ago
# 5           Less than a year ago
# 6                  1-2 years ago
# 8                            NaN
# ...                          ...
# 87739                        NaN
# 88182                        NaN
# 88282                        NaN
# 88377                        NaN
# 88863                        NaN
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 1                                                         NaN      NaN
# 3                         Interview with people in peer roles       No
# 5           Write any code;Write code by hand (e.g., on a ...       No
# 6           Write any code;Complete a take-home project;In...       No
# 8                                                         NaN      NaN
# ...                                                       ...      ...
# 87739                                                     NaN      NaN
# 88182                                                     NaN      NaN
# 88282                                                     NaN      NaN
# 88377                                                     NaN      NaN
# 88863                                                     NaN      NaN
#
#                                                    JobFactors  \
# Respondent
# 1                                                         NaN
# 3           Languages, frameworks, and other technologies ...
# 5           Industry that I'd be working in;Languages, fra...
# 6           Financial performance or funding status of the...
# 8                                                         NaN
# ...                                                       ...
# 87739                                                     NaN
# 88182                                                     NaN
# 88282                                                     NaN
# 88377                                                     NaN
# 88863                                                     NaN
#
#                                                  ResumeUpdate CurrencySymbol  \
# Respondent
# 1                                                         NaN            NaN
# 3                            I was preparing for a job search            THB
# 5                            I was preparing for a job search            UAH
# 6           I heard about a job opportunity (from a recrui...            CAD
# 8                                                         NaN            NaN
# ...                                                       ...            ...
# 87739                                                     NaN            NaN
# 88182                                                     NaN            NaN
# 88282                                                     NaN            NaN
# 88377                                                     NaN            NaN
# 88863                                                     NaN            NaN
#
#                  CurrencyDesc  CompTotal CompFreq  SalaryUSD  WorkWeekHrs  \
# Respondent
# 1                         NaN        NaN      NaN        NaN          NaN
# 3                   Thai baht    23000.0  Monthly     8820.0         40.0
# 5           Ukrainian hryvnia        NaN      NaN        NaN         55.0
# 6             Canadian dollar    40000.0  Monthly   366420.0         15.0
# 8                         NaN        NaN      NaN        NaN          NaN
# ...                       ...        ...      ...        ...          ...
# 87739                     NaN        NaN      NaN        NaN          NaN
# 88182                     NaN        NaN      NaN        NaN          NaN
# 88282                     NaN        NaN      NaN        NaN          NaN
# 88377                     NaN        NaN      NaN        NaN          NaN
# 88863                     NaN        NaN      NaN        NaN          NaN
#
#                                                      WorkPlan  \
# Respondent
# 1                                                         NaN
# 3           There's no schedule or spec; I work on what se...
# 5           There is a schedule and/or spec (made by me or...
# 6           There's no schedule or spec; I work on what se...
# 8                                                         NaN
# ...                                                       ...
# 87739                                                     NaN
# 88182                                                     NaN
# 88282                                                     NaN
# 88377                                                     NaN
# 88863                                                     NaN
#
#                                                 WorkChallenge  \
# Respondent
# 1                                                         NaN
# 3           Distracting work environment;Inadequate access...
# 5           Being tasked with non-development work;Inadequ...
# 6                                                         NaN
# 8                                                         NaN
# ...                                                       ...
# 87739                                                     NaN
# 88182                                                     NaN
# 88282                                                     NaN
# 88377                                                     NaN
# 88863                                                     NaN
#
#                                   WorkRemote WorkLoc                  ImpSyn  \
# Respondent
# 1                                        NaN     NaN                     NaN
# 3           Less than once per month / Never    Home                 Average
# 5                      A few days each month  Office  A little above average
# 6                      A few days each month    Home  A little above average
# 8                                        NaN     NaN                     NaN
# ...                                      ...     ...                     ...
# 87739                                    NaN     NaN                     NaN
# 88182                                    NaN     NaN                     NaN
# 88282                                    NaN     NaN                     NaN
# 88377                                    NaN     NaN                     NaN
# 88863                                    NaN     NaN                     NaN
#
#                                             CodeRev  CodeRevHrs  \
# Respondent
# 1                                               NaN         NaN
# 3                                                No         NaN
# 5           Yes, because I see value in code review         NaN
# 6                                                No         NaN
# 8                                               NaN         NaN
# ...                                             ...         ...
# 87739                                           NaN         NaN
# 88182                                           NaN         NaN
# 88282                                           NaN         NaN
# 88377                                           NaN         NaN
# 88863                                           NaN         NaN
#
#                                                     UnitTests PurchaseHow  \
# Respondent
# 1                                                         NaN         NaN
# 3                                   No, but I think we should    Not sure
# 5                               Yes, it's part of our process    Not sure
# 6           Yes, it's not part of our process but the deve...    Not sure
# 8                                                         NaN         NaN
# ...                                                       ...         ...
# 87739                                                     NaN         NaN
# 88182                                                     NaN         NaN
# 88282                                                     NaN         NaN
# 88377                                                     NaN         NaN
# 88863                                                     NaN         NaN
#
#                              PurchaseWhat  \
# Respondent
# 1                                     NaN
# 3           I have little or no influence
# 5           I have little or no influence
# 6           I have little or no influence
# 8                                     NaN
# ...                                   ...
# 87739                                 NaN
# 88182                                 NaN
# 88282                                 NaN
# 88377                                 NaN
# 88863                                 NaN
#
#                                            LanguageWorkedWith  \
# Respondent
# 1                             HTML/CSS;Java;JavaScript;Python
# 3                                                    HTML/CSS
# 5                 C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 6                                                  Java;R;SQL
# 8           Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# ...                                                       ...
# 87739                C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88182                                HTML/CSS;Java;JavaScript
# 88282       Bash/Shell/PowerShell;Go;HTML/CSS;JavaScript;W...
# 88377                           HTML/CSS;JavaScript;Other(s):
# 88863       Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
#
#                                        LanguageDesireNextYear  \
# Respondent
# 1             C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 3                                             Elixir;HTML/CSS
# 5                    HTML/CSS;Java;JavaScript;SQL;WebAssembly
# 6                                            Python;Scala;SQL
# 8           Bash/Shell/PowerShell;C;C++;Elixir;Erlang;Go;P...
# ...                                                       ...
# 87739                                 C++;HTML/CSS;PHP;Python
# 88182                                                     NaN
# 88282       Bash/Shell/PowerShell;C;Go;HTML/CSS;JavaScript...
# 88377       C++;HTML/CSS;JavaScript;SQL;WebAssembly;Other(s):
# 88863            C;C++;C#;HTML/CSS;Java;Objective-C;SQL;Swift
#
#                                            DatabaseWorkedWith  \
# Respondent
# 1                                                      SQLite
# 3                                                  PostgreSQL
# 5            Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
# 6                                          MongoDB;PostgreSQL
# 8           Cassandra;Elasticsearch;MongoDB;MySQL;Oracle;R...
# ...                                                       ...
# 87739                                                   MySQL
# 88182                                                     NaN
# 88282                                                     NaN
# 88377                                         Firebase;SQLite
# 88863             DynamoDB;MariaDB;Microsoft SQL Server;MySQL
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 1                                                       MySQL
# 3                                                  PostgreSQL
# 5           Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
# 6                                                  PostgreSQL
# 8           Cassandra;DynamoDB;Elasticsearch;Firebase;Mong...
# ...                                                       ...
# 87739                                                   MySQL
# 88182                                                     NaN
# 88282                                                     NaN
# 88377                                   Firebase;MySQL;SQLite
# 88863                             MariaDB;MySQL;Oracle;SQLite
#
#                                      PlatformWorkedWith  \
# Respondent
# 1                                         MacOS;Windows
# 3                                                   NaN
# 5                     Android;Linux;MacOS;Slack;Windows
# 6           Android;Google Cloud Platform;Linux;Windows
# 8                   AWS;Docker;Heroku;Linux;MacOS;Slack
# ...                                                 ...
# 87739                           Android;Linux;WordPress
# 88182                             Google Cloud Platform
# 88282                                             Linux
# 88377                                             Linux
# 88863                         iOS;Linux;MacOS;WordPress
#
#                                        PlatformDesireNextYear  \
# Respondent
# 1                                     Android;Arduino;Windows
# 3                                                         NaN
# 5                       Android;Docker;Kubernetes;Linux;Slack
# 6                 Android;Google Cloud Platform;Linux;Windows
# 8           Android;Arduino;AWS;Docker;Google Cloud Platfo...
# ...                                                       ...
# 87739                                           Android;Linux
# 88182                                                     NaN
# 88282                                      Linux;Raspberry Pi
# 88377                             Google Cloud Platform;Linux
# 88863       Android;AWS;Google Cloud Platform;IBM Cloud or...
#
#                                      WebFrameWorkedWith  \
# Respondent
# 1                                          Django;Flask
# 3                                                   NaN
# 5           Django;Express;Flask;jQuery;React.js;Spring
# 6                                                   NaN
# 8                         Express;Flask;React.js;Spring
# ...                                                 ...
# 87739                                            jQuery
# 88182                                         Other(s):
# 88282                                          React.js
# 88377                                            jQuery
# 88863                            Django;jQuery;React.js
#
#                           WebFrameDesireNextYear      MiscTechWorkedWith  \
# Respondent
# 1                                   Flask;jQuery                 Node.js
# 3                                      Other(s):                     NaN
# 5                   Flask;jQuery;React.js;Spring         Cordova;Node.js
# 6                                            NaN                  Hadoop
# 8           Django;Express;Flask;React.js;Vue.js   Hadoop;Node.js;Pandas
# ...                                          ...                     ...
# 87739                                     jQuery              TensorFlow
# 88182                                        NaN               Other(s):
# 88282                                     Vue.js                 Node.js
# 88377                              jQuery;Vue.js                 Node.js
# 88863                                     Django  Unity 3D;Unreal Engine
#
#                                        MiscTechDesireNextYear  \
# Respondent
# 1                                                     Node.js
# 3                                                         NaN
# 5                    Apache Spark;Hadoop;Node.js;React Native
# 6                           Hadoop;Pandas;TensorFlow;Unity 3D
# 8           Ansible;Apache Spark;Chef;Hadoop;Node.js;Panda...
# ...                                                       ...
# 87739                                                     NaN
# 88182                                                     NaN
# 88282                                                 Ansible
# 88377                     React Native;Unity 3D;Unreal Engine
# 88863                                                     NaN
#
#                                                    DevEnviron        OpSys  \
# Respondent
# 1                                  IntelliJ;Notepad++;PyCharm      Windows
# 3                                      Vim;Visual Studio Code  Linux-based
# 5                                      IntelliJ;Notepad++;Vim  Linux-based
# 6           Android Studio;Eclipse;PyCharm;RStudio;Visual ...      Windows
# 8           Atom;IntelliJ;IPython / Jupyter;PyCharm;Visual...  Linux-based
# ...                                                       ...          ...
# 87739                                                     Vim  Linux-based
# 88182                                          Android Studio      Windows
# 88282                                                     Vim  Linux-based
# 88377                   Atom;Visual Studio;Visual Studio Code      Windows
# 88863       Android Studio;Atom;Eclipse;NetBeans;Notepad++...  Linux-based
#
#                                                    Containers BlockchainOrg  \
# Respondent
# 1                                     I do not use containers           NaN
# 3                                     I do not use containers           NaN
# 5                      Outside of work, for personal projects    Not at all
# 6                                     I do not use containers    Not at all
# 8           Development;Testing;Production;Outside of work...           NaN
# ...                                                       ...           ...
# 87739                                 I do not use containers           NaN
# 88182                                             Development           NaN
# 88282                                 I do not use containers           NaN
# 88377                                 I do not use containers           NaN
# 88863                                              Production           NaN
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 1                                                         NaN        Yes
# 3                                                         NaN        Yes
# 5                                                         NaN        Yes
# 6                                                         NaN         No
# 8           Useful across many domains and could change ma...        Yes
# ...                                                       ...        ...
# 87739                                           A passing fad         No
# 88182       Useful across many domains and could change ma...        Yes
# 88282                       An irresponsible use of resources         No
# 88377       Useful across many domains and could change ma...        Yes
# 88863       Useful for decentralized currency (i.e., Bitcoin)        Yes
#
#                                             ITperson  OffOn  \
# Respondent
# 1           Fortunately, someone else has that title    Yes
# 3                                                Yes    Yes
# 5                                           Also Yes    Yes
# 6                                                Yes     No
# 8                                               SIGH    Yes
# ...                                              ...    ...
# 87739                                            Yes    Yes
# 88182                                       Also Yes  What?
# 88282                                            NaN    Yes
# 88377                                            Yes  What?
# 88863                                       Also Yes    Yes
#
#                          SocialMedia              Extraversion ScreenName  \
# Respondent
# 1                            Twitter                    Online   Username
# 3                             Reddit  In real life (in person)   Username
# 5                           Facebook  In real life (in person)   Username
# 6                            YouTube  In real life (in person)      Login
# 8                            YouTube  In real life (in person)     Handle
# ...                              ...                       ...        ...
# 87739                        YouTube  In real life (in person)      Login
# 88182                        Twitter                   Neither   Username
# 88282       I don't use social media  In real life (in person)   Username
# 88377                        YouTube                       NaN   Username
# 88863                       WhatsApp  In real life (in person)        NaN
#
#                   SOVisit1st  \
# Respondent
# 1                       2017
# 3                       2011
# 5           I don't remember
# 6                       2011
# 8                       2012
# ...                      ...
# 87739                   2009
# 88182                    NaN
# 88282       I don't remember
# 88377       I don't remember
# 88863                   2012
#
#                                                   SOVisitFreq  \
# Respondent
# 1                             A few times per month or weekly
# 3                                        A few times per week
# 5                                      Multiple times per day
# 6                             A few times per month or weekly
# 8                                        A few times per week
# ...                                                       ...
# 87739                         A few times per month or weekly
# 88182       I have never visited Stack Overflow (before to...
# 88282                         A few times per month or weekly
# 88377                                    A few times per week
# 88863                                   Daily or almost daily
#
#                                                     SOVisitTo  \
# Respondent
# 1           Find answers to specific questions;Learn how t...
# 3           Find answers to specific questions;Learn how t...
# 5                          Find answers to specific questions
# 6                          Find answers to specific questions
# 8           Find answers to specific questions;Learn how t...
# ...                                                       ...
# 87739                      Find answers to specific questions
# 88182       Get a sense of belonging to the developer comm...
# 88282                      Find answers to specific questions
# 88377       Find answers to specific questions;Learn how t...
# 88863       Find answers to specific questions;Learn how t...
#
#                            SOFindAnswer  \
# Respondent
# 1                    3-5 times per week
# 3                   6-10 times per week
# 5           More than 10 times per week
# 6               Less than once per week
# 8               Less than once per week
# ...                                 ...
# 87739                1-2 times per week
# 88182           Less than once per week
# 88282                1-2 times per week
# 88377                3-5 times per week
# 88863               6-10 times per week
#
#                                        SOTimeSaved  SOHowMuchTime SOAccount  \
# Respondent
# 1                   Stack Overflow was much faster  31-60 minutes        No
# 3                         They were about the same            NaN       Yes
# 5                   Stack Overflow was much faster            NaN       Yes
# 6               Stack Overflow was slightly faster    60+ minutes       Yes
# 8               Stack Overflow was slightly faster  11-30 minutes       Yes
# ...                                            ...            ...       ...
# 87739               Stack Overflow was much faster  31-60 minutes       Yes
# 88182       The other resource was slightly faster    60+ minutes       NaN
# 88282                     They were about the same            NaN       Yes
# 88377           Stack Overflow was slightly faster  11-30 minutes       Yes
# 88863               Stack Overflow was much faster  11-30 minutes       Yes
#
#                                                    SOPartFreq  \
# Respondent
# 1                                                         NaN
# 3                         Less than once per month or monthly
# 5                             A few times per month or weekly
# 6           I have never participated in Q&A on Stack Over...
# 8                         Less than once per month or monthly
# ...                                                       ...
# 87739                         A few times per month or weekly
# 88182                                                     NaN
# 88282       I have never participated in Q&A on Stack Over...
# 88377       I have never participated in Q&A on Stack Over...
# 88863                         A few times per month or weekly
#
#                                                        SOJobs  \
# Respondent
# 1           No, I didn't know that Stack Overflow had a jo...
# 3                                                         Yes
# 5           No, I knew that Stack Overflow had a job board...
# 6           No, I knew that Stack Overflow had a job board...
# 8                                                         Yes
# ...                                                       ...
# 87739       No, I knew that Stack Overflow had a job board...
# 88182       No, I didn't know that Stack Overflow had a jo...
# 88282                                                     Yes
# 88377       No, I knew that Stack Overflow had a job board...
# 88863                                                     Yes
#
#                                                      EntTeams  \
# Respondent
# 1                         No, and I don't know what those are
# 3           No, I've heard of them, but I am not part of a...
# 5           No, I've heard of them, but I am not part of a...
# 6                         No, and I don't know what those are
# 8                         No, and I don't know what those are
# ...                                                       ...
# 87739                     No, and I don't know what those are
# 88182                     No, and I don't know what those are
# 88282                     No, and I don't know what those are
# 88377       No, I've heard of them, but I am not part of a...
# 88863       No, I've heard of them, but I am not part of a...
#
#                      SOComm  \
# Respondent
# 1                   Neutral
# 3                   Neutral
# 5           Yes, definitely
# 6            No, not really
# 8           Yes, definitely
# ...                     ...
# 87739               Neutral
# 88182               Neutral
# 88282        No, not really
# 88377        No, not at all
# 88863         Yes, somewhat
#
#                                                 WelcomeChange  \
# Respondent
# 1                     Just as welcome now as I felt last year
# 3                     Just as welcome now as I felt last year
# 5                     Just as welcome now as I felt last year
# 6                     Just as welcome now as I felt last year
# 8                       A lot more welcome now than last year
# ...                                                       ...
# 87739                 Just as welcome now as I felt last year
# 88182       Not applicable - I did not use Stack Overflow ...
# 88282                 Just as welcome now as I felt last year
# 88377                                                     NaN
# 88863                Somewhat less welcome now than last year
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 1           Tech articles written by other developers;Indu...  14.0    Man
# 3           Tech meetups or events in your area;Courses on...  28.0    Man
# 5           Tech meetups or events in your area;Courses on...  30.0    Man
# 6           Tech articles written by other developers;Indu...  28.0    Man
# 8           Tech articles written by other developers;Indu...  24.0    Man
# ...                                                       ...   ...    ...
# 87739                                                     NaN  25.0    NaN
# 88182            Courses on technologies you're interested in   NaN    Man
# 88282                                                     NaN   NaN    Man
# 88377       Tech articles written by other developers;Tech...   NaN    Man
# 88863       Tech articles written by other developers;Indu...  18.0    Man
#
#            Trans                Sexuality  \
# Respondent
# 1             No  Straight / Heterosexual
# 3             No  Straight / Heterosexual
# 5             No  Straight / Heterosexual
# 6             No  Straight / Heterosexual
# 8             No  Straight / Heterosexual
# ...          ...                      ...
# 87739         No  Straight / Heterosexual
# 88182         No  Straight / Heterosexual
# 88282         No  Straight / Heterosexual
# 88377         No                      NaN
# 88863         No  Straight / Heterosexual
#
#                                                     Ethnicity Dependents  \
# Respondent
# 1                                                         NaN         No
# 3                                                         NaN        Yes
# 5                    White or of European descent;Multiracial         No
# 6                                                  East Asian         No
# 8                                                         NaN        NaN
# ...                                                       ...        ...
# 87739                            White or of European descent         No
# 88182                                                     NaN        Yes
# 88282                                                     NaN         No
# 88377                                                     NaN         No
# 88863       Hispanic or Latino/Latina;White or of European...         No
#
#                      SurveyLength                  SurveyEase
# Respondent
# 1           Appropriate in length  Neither easy nor difficult
# 3           Appropriate in length  Neither easy nor difficult
# 5           Appropriate in length                        Easy
# 6                        Too long  Neither easy nor difficult
# 8           Appropriate in length  Neither easy nor difficult
# ...                           ...                         ...
# 87739       Appropriate in length                        Easy
# 88182                   Too short  Neither easy nor difficult
# 88282                   Too short  Neither easy nor difficult
# 88377       Appropriate in length                        Easy
# 88863       Appropriate in length                        Easy
#
# [71257 rows x 84 columns]

# %%
df_survey['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df_survey['Employment'].value_counts()
# Out:
# Employed full-time                                      64440
# Independent contractor, freelancer, or self-employed     8511
# Not employed, but looking for work                       5600
# Employed part-time                                       4469
# Not employed, and not looking for work                   3803
# Retired                                                   358
# Name: Employment, dtype: int64

# %% [markdown]
# # EDA

# %%
salary_data_graph.
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 511                            I am a developer by profession      Yes
# 1599        I am not primarily a developer, but I write co...      Yes
# 1715                           I am a developer by profession      Yes
# 2142                           I am a developer by profession      Yes
# 2434                           I am a developer by profession      Yes
# ...                                                       ...      ...
# 87298       I am not primarily a developer, but I write co...      Yes
# 87508                          I am a developer by profession      Yes
# 88137                          I am a developer by profession      Yes
# 88364                          I am a developer by profession      Yes
# 88672                          I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 511                                   Less than once per year
# 1599                                                    Never
# 1715                               Once a month or more often
# 2142                                                    Never
# 2434                                                    Never
# ...                                                       ...
# 87298                              Once a month or more often
# 87508       Less than once a month but more than once per ...
# 88137                                 Less than once per year
# 88364       Less than once a month but more than once per ...
# 88672                                                   Never
#
#                                                    OpenSource  \
# Respondent
# 511         OSS is, on average, of HIGHER quality than pro...
# 1599        OSS is, on average, of HIGHER quality than pro...
# 1715        The quality of OSS and closed source software ...
# 2142                                                      NaN
# 2434        OSS is, on average, of LOWER quality than prop...
# ...                                                       ...
# 87298       The quality of OSS and closed source software ...
# 87508       OSS is, on average, of HIGHER quality than pro...
# 88137       The quality of OSS and closed source software ...
# 88364       OSS is, on average, of HIGHER quality than pro...
# 88672       The quality of OSS and closed source software ...
#
#                                                    Employment        Country  \
# Respondent
# 511         Independent contractor, freelancer, or self-em...      Singapore
# 1599                                       Employed full-time  United States
# 1715        Independent contractor, freelancer, or self-em...  United States
# 2142                                       Employed full-time  United States
# 2434        Independent contractor, freelancer, or self-em...  United States
# ...                                                       ...            ...
# 87298                                      Employed full-time  United States
# 87508                                      Employed full-time  United States
# 88137                                      Employed full-time  United States
# 88364                                      Employed full-time  United States
# 88672                                      Employed full-time  United States
#
#            Student                                            EdLevel  \
# Respondent
# 511             No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1599            No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 1715            No          Other doctoral degree (Ph.D, Ed.D., etc.)
# 2142            No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2434            No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...            ...                                                ...
# 87298           No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 87508           No                                   Associate degree
# 88137           No  Some college/university study without earning ...
# 88364           No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88672           No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                                UndergradMajor  \
# Respondent
# 511         Computer science, computer engineering, or sof...
# 1599        A natural science (ex. biology, chemistry, phy...
# 1715        A natural science (ex. biology, chemistry, phy...
# 2142        Computer science, computer engineering, or sof...
# 2434        Computer science, computer engineering, or sof...
# ...                                                       ...
# 87298       Computer science, computer engineering, or sof...
# 87508       A humanities discipline (ex. literature, histo...
# 88137       Information systems, information technology, o...
# 88364       Computer science, computer engineering, or sof...
# 88672       Computer science, computer engineering, or sof...
#
#                                                      EduOther  \
# Respondent
# 511         Taught yourself a new language, framework, or ...
# 1599        Received on-the-job training in software devel...
# 1715        Received on-the-job training in software devel...
# 2142        Taught yourself a new language, framework, or ...
# 2434        Taught yourself a new language, framework, or ...
# ...                                                       ...
# 87298       Taken an online course in programming or softw...
# 87508       Taken an online course in programming or softw...
# 88137       Taken an online course in programming or softw...
# 88364       Taken an online course in programming or softw...
# 88672       Taken an online course in programming or softw...
#
#                                                       OrgSize  \
# Respondent
# 511         Just me - I am a freelancer, sole proprietor, ...
# 1599                                       10 to 19 employees
# 1715                                       10 to 19 employees
# 2142                                 10,000 or more employees
# 2434                                       10 to 19 employees
# ...                                                       ...
# 87298                                10,000 or more employees
# 87508                                      20 to 99 employees
# 88137                                      20 to 99 employees
# 88364                                1,000 to 4,999 employees
# 88672                                10,000 or more employees
#
#                                                       DevType YearsCode  \
# Respondent
# 511         Developer, full-stack;Developer, mobile;Engine...        15
# 1599        Data or business analyst;Data scientist or mac...        25
# 1715                                    Developer, full-stack        16
# 2142                                      Developer, back-end        10
# 2434        Academic researcher;Data or business analyst;D...        30
# ...                                                       ...       ...
# 87298                                     Developer, back-end        40
# 87508       Developer, front-end;Developer, full-stack;Sen...        25
# 88137       Data or business analyst;Data scientist or mac...        36
# 88364       Developer, back-end;Developer, desktop or ente...         8
# 88672       Developer, back-end;Developer, embedded applic...        40
#
#            Age1stCode YearsCodePro           CareerSat              JobSat  \
# Respondent
# 511                15           10   Very dissatisfied   Very dissatisfied
# 1599               19           20      Very satisfied      Very satisfied
# 1715               10           10      Very satisfied      Very satisfied
# 2142               13            6      Very satisfied      Very satisfied
# 2434               10           21      Very satisfied      Very satisfied
# ...               ...          ...                 ...                 ...
# 87298              12           20      Very satisfied      Very satisfied
# 87508               7           23      Very satisfied      Very satisfied
# 88137               8           21      Very satisfied      Very satisfied
# 88364              14            4  Slightly satisfied   Very dissatisfied
# 88672              15           37      Very satisfied  Slightly satisfied
#
#                         MgrIdiot MgrMoney                 MgrWant  \
# Respondent
# 511                          NaN      NaN                     NaN
# 1599                         NaN      NaN                     NaN
# 1715                         NaN      NaN                     NaN
# 2142              Very confident       No                      No
# 2434                         NaN      NaN                     NaN
# ...                          ...      ...                     ...
# 87298             Very confident      Yes                      No
# 87508                        NaN      NaN                     NaN
# 88137                        NaN      NaN                     NaN
# 88364         Somewhat confident       No                     Yes
# 88672       Not at all confident       No  I am already a manager
#
#                                                       JobSeek  \
# Respondent
# 511              I am not interested in new job opportunities
# 1599        I’m not actively looking, but I am open to new...
# 1715        I’m not actively looking, but I am open to new...
# 2142        I’m not actively looking, but I am open to new...
# 2434        I’m not actively looking, but I am open to new...
# ...                                                       ...
# 87298            I am not interested in new job opportunities
# 87508            I am not interested in new job opportunities
# 88137       I’m not actively looking, but I am open to new...
# 88364                         I am actively looking for a job
# 88672            I am not interested in new job opportunities
#
#                                                  LastHireDate  \
# Respondent
# 511         NA - I am an independent contractor or self em...
# 1599                                            1-2 years ago
# 1715                                            1-2 years ago
# 2142                                            1-2 years ago
# 2434                                     Less than a year ago
# ...                                                       ...
# 87298                                   More than 4 years ago
# 87508                                   More than 4 years ago
# 88137                                   More than 4 years ago
# 88364                                           1-2 years ago
# 88672                                   More than 4 years ago
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 511         Write any code;Write code by hand (e.g., on a ...       No
# 1599        Interview with people in peer roles;Interview ...       No
# 1715        Write any code;Complete a take-home project;In...      Yes
# 2142        Write any code;Write code by hand (e.g., on a ...       No
# 2434                                                      NaN       No
# ...                                                       ...      ...
# 87298       Write any code;Write code by hand (e.g., on a ...       No
# 87508       Write any code;Write code by hand (e.g., on a ...       No
# 88137       Write any code;Write code by hand (e.g., on a ...       No
# 88364       Write any code;Write code by hand (e.g., on a ...      Yes
# 88672       Interview with people in peer roles;Interview ...       No
#
#                                                    JobFactors  \
# Respondent
# 511         Languages, frameworks, and other technologies ...
# 1599        Specific department or team I'd be working on;...
# 1715        Financial performance or funding status of the...
# 2142        Specific department or team I'd be working on;...
# 2434        Languages, frameworks, and other technologies ...
# ...                                                       ...
# 87298       Specific department or team I'd be working on;...
# 87508       Languages, frameworks, and other technologies ...
# 88137       Financial performance or funding status of the...
# 88364       Financial performance or funding status of the...
# 88672       Languages, frameworks, and other technologies ...
#
#                                                  ResumeUpdate CurrencySymbol  \
# Respondent
# 511                          I was preparing for a job search            USD
# 1599        I heard about a job opportunity (from a recrui...            USD
# 1715        I heard about a job opportunity (from a recrui...            USD
# 2142                         I was preparing for a job search            USD
# 2434                         I was preparing for a job search            USD
# ...                                                       ...            ...
# 87298                        I was preparing for a job search            USD
# 87508                        I was preparing for a job search            USD
# 88137                        I was preparing for a job search            USD
# 88364                        I was preparing for a job search            USD
# 88672       I heard about a job opportunity (from a recrui...            USD
#
#                     CurrencyDesc  CompTotal CompFreq  SalaryUSD  WorkWeekHrs  \
# Respondent
# 511         United States dollar   400000.0   Yearly   400000.0         25.0
# 1599        United States dollar   400000.0   Yearly   400000.0         60.0
# 1715        United States dollar   350000.0   Yearly   350000.0         80.0
# 2142        United States dollar   330000.0   Yearly   330000.0         45.0
# 2434        United States dollar   400000.0   Yearly   400000.0         40.0
# ...                          ...        ...      ...        ...          ...
# 87298       United States dollar   400000.0   Yearly   400000.0         50.0
# 87508       United States dollar   400000.0   Yearly   400000.0         50.0
# 88137       United States dollar   400000.0   Yearly   400000.0         80.0
# 88364       United States dollar   325000.0   Yearly   325000.0         40.0
# 88672       United States dollar   350000.0   Yearly   350000.0         10.0
#
#                                                      WorkPlan  \
# Respondent
# 511         There's no schedule or spec; I work on what se...
# 1599        There is a schedule and/or spec (made by me or...
# 1715        There is a schedule and/or spec (made by me or...
# 2142        There's no schedule or spec; I work on what se...
# 2434        There's no schedule or spec; I work on what se...
# ...                                                       ...
# 87298       There's no schedule or spec; I work on what se...
# 87508       There is a schedule and/or spec (made by me or...
# 88137       There's no schedule or spec; I work on what se...
# 88364       There is a schedule and/or spec (made by me or...
# 88672       There is a schedule and/or spec (made by me or...
#
#                                                 WorkChallenge  \
# Respondent
# 511         Meetings;Not enough people for the workload;Ti...
# 1599        Being tasked with non-development work;Distrac...
# 1715        Lack of support from management;Meetings;Non-w...
# 2142        Being tasked with non-development work;Distrac...
# 2434        Non-work commitments (parenting, school work, ...
# ...                                                       ...
# 87298       Being tasked with non-development work;Distrac...
# 87508                  Being tasked with non-development work
# 88137       Being tasked with non-development work;Distrac...
# 88364       Distracting work environment;Time spent commut...
# 88672       Being tasked with non-development work;Inadequ...
#
#                                                    WorkRemote  \
# Respondent
# 511         All or almost all the time (I'm full-time remote)
# 1599                                    A few days each month
# 1715        All or almost all the time (I'm full-time remote)
# 2142                                    A few days each month
# 2434                    More than half, but not all, the time
# ...                                                       ...
# 87298       All or almost all the time (I'm full-time remote)
# 87508                                   A few days each month
# 88137                   More than half, but not all, the time
# 88364       Less than half the time, but at least one day ...
# 88672                                   A few days each month
#
#                                                    WorkLoc  \
# Respondent
# 511         Other place, such as a coworking space or cafe
# 1599                                                Office
# 1715                                                  Home
# 2142                                                Office
# 2434                                                  Home
# ...                                                    ...
# 87298                                                 Home
# 87508                                                 Home
# 88137                                                 Home
# 88364                                               Office
# 88672                                               Office
#
#                             ImpSyn                                  CodeRev  \
# Respondent
# 511              Far above average         Yes, because I was told to do so
# 1599             Far above average  Yes, because I see value in code review
# 1715        A little above average  Yes, because I see value in code review
# 2142        A little above average  Yes, because I see value in code review
# 2434             Far above average  Yes, because I see value in code review
# ...                            ...                                      ...
# 87298            Far above average                                       No
# 87508            Far above average  Yes, because I see value in code review
# 88137            Far above average                                       No
# 88364                      Average         Yes, because I was told to do so
# 88672                      Average                                       No
#
#             CodeRevHrs                      UnitTests  \
# Respondent
# 511                1.0                            NaN
# 1599               5.0  Yes, it's part of our process
# 1715              10.0                            NaN
# 2142               2.0  Yes, it's part of our process
# 2434               1.0                            NaN
# ...                ...                            ...
# 87298              NaN  Yes, it's part of our process
# 87508              6.0  Yes, it's part of our process
# 88137              NaN      No, and I'm glad we don't
# 88364             10.0  Yes, it's part of our process
# 88672              NaN  Yes, it's part of our process
#
#                                                   PurchaseHow  \
# Respondent
# 511                                                       NaN
# 1599        Developers and management have nearly equal in...
# 1715                                                      NaN
# 2142                                                 Not sure
# 2434                                                      NaN
# ...                                                       ...
# 87298                                                     NaN
# 87508       Developers and management have nearly equal in...
# 88137       The CTO, CIO, or other management purchase new...
# 88364                                                Not sure
# 88672       Developers typically have the most influence o...
#
#                                 PurchaseWhat  \
# Respondent
# 511                                      NaN
# 1599        I have a great deal of influence
# 1715                                     NaN
# 2142                                     NaN
# 2434                                     NaN
# ...                                      ...
# 87298          I have little or no influence
# 87508       I have a great deal of influence
# 88137       I have a great deal of influence
# 88364          I have little or no influence
# 88672       I have a great deal of influence
#
#                                            LanguageWorkedWith  \
# Respondent
# 511                   HTML/CSS;JavaScript;Ruby;SQL;TypeScript
# 1599        C;C++;C#;HTML/CSS;Java;JavaScript;Kotlin;Rust;...
# 1715        Bash/Shell/PowerShell;C;C++;C#;Clojure;HTML/CS...
# 2142                    Bash/Shell/PowerShell;Java;Python;SQL
# 2434                     Java;JavaScript;Python;SQL;Other(s):
# ...                                                       ...
# 87298       Bash/Shell/PowerShell;C#;Go;HTML/CSS;JavaScrip...
# 87508                         HTML/CSS;Java;JavaScript;Python
# 88137       Bash/Shell/PowerShell;C;C++;Go;HTML/CSS;Java;J...
# 88364                                          C++;Python;SQL
# 88672                                                   C;C++
#
#                                        LanguageDesireNextYear  \
# Respondent
# 511                                                  HTML/CSS
# 1599                       C#;Go;Kotlin;Rust;Swift;TypeScript
# 1715        Bash/Shell/PowerShell;C;C++;C#;Clojure;HTML/CS...
# 2142                                           Go;Java;Python
# 2434                                  Java;Python;R;Other(s):
# ...                                                       ...
# 87298              Bash/Shell/PowerShell;Go;JavaScript;Python
# 87508                         HTML/CSS;JavaScript;WebAssembly
# 88137       Bash/Shell/PowerShell;C;C++;Go;HTML/CSS;JavaSc...
# 88364                                      C++;Go;Python;Rust
# 88672                                                   C;C++
#
#                                            DatabaseWorkedWith  \
# Respondent
# 511             Elasticsearch;MongoDB;PostgreSQL;Redis;SQLite
# 1599                              Microsoft SQL Server;SQLite
# 1715        Cassandra;DynamoDB;Elasticsearch;MySQL;Postgre...
# 2142                                                   Oracle
# 2434                                        PostgreSQL;SQLite
# ...                                                       ...
# 87298                                                     NaN
# 87508                       Elasticsearch;Firebase;PostgreSQL
# 88137                                      MySQL;Redis;SQLite
# 88364                                                     NaN
# 88672                                                     NaN
#
#                                    DatabaseDesireNextYear  \
# Respondent
# 511                       MongoDB;PostgreSQL;Redis;SQLite
# 1599               Microsoft SQL Server;PostgreSQL;SQLite
# 1715        Cassandra;DynamoDB;PostgreSQL;Redis;Other(s):
# 2142                                                  NaN
# 2434                                                  NaN
# ...                                                   ...
# 87298                                                 NaN
# 87508                              DynamoDB;Elasticsearch
# 88137               Couchbase;Firebase;MySQL;Redis;SQLite
# 88364                                       MongoDB;Redis
# 88672                             Cassandra;MongoDB;Redis
#
#                                            PlatformWorkedWith  \
# Respondent
# 511                               AWS;Docker;Heroku;iOS;Slack
# 1599                                Android;iOS;MacOS;Windows
# 1715        AWS;Docker;Heroku;iOS;Kubernetes;Linux;MacOS;M...
# 2142                                                      NaN
# 2434                     AWS;Docker;Linux;MacOS;Slack;Windows
# ...                                                       ...
# 87298       Docker;Google Cloud Platform;Kubernetes;Linux;...
# 87508                                 AWS;Linux;MacOS;Windows
# 88137                                               iOS;Linux
# 88364                             Google Cloud Platform;Linux
# 88672                                                   Linux
#
#                                        PlatformDesireNextYear  \
# Respondent
# 511                                          Heroku;iOS;Slack
# 1599                                Android;iOS;MacOS;Windows
# 1715        AWS;Docker;iOS;Kubernetes;Linux;MacOS;Microsof...
# 2142                                                      NaN
# 2434                           AWS;Docker;Linux;MacOS;Windows
# ...                                                       ...
# 87298       Docker;Google Cloud Platform;Kubernetes;Linux;...
# 87508                                               AWS;MacOS
# 88137                                               iOS;Linux
# 88364                        Google Cloud Platform;Kubernetes
# 88672                            AWS;Kubernetes;Linux;Windows
#
#                                         WebFrameWorkedWith  \
# Respondent
# 511                                       Express;React.js
# 1599                                 ASP.NET;Django;jQuery
# 1715        Django;jQuery;React.js;Ruby on Rails;Other(s):
# 2142                                             Other(s):
# 2434                             Angular/Angular.js;Django
# ...                                                    ...
# 87298                                                  NaN
# 87508                               jQuery;React.js;Vue.js
# 88137                            Angular/Angular.js;jQuery
# 88364                                                  NaN
# 88672                                                  NaN
#
#                                 WebFrameDesireNextYear  \
# Respondent
# 511                                   Express;React.js
# 1599        Angular/Angular.js;ASP.NET;React.js;Vue.js
# 1715           Django;jQuery;React.js;Vue.js;Other(s):
# 2142                                         Other(s):
# 2434                                            Django
# ...                                                ...
# 87298                                              NaN
# 87508                                  jQuery;React.js
# 88137                        Angular/Angular.js;jQuery
# 88364                                              NaN
# 88672                                              NaN
#
#                              MiscTechWorkedWith  \
# Respondent
# 511                        Node.js;React Native
# 1599        .NET;.NET Core;Node.js;React Native
# 1715             Ansible;.NET;.NET Core;Node.js
# 2142                                        NaN
# 2434                          Pandas;TensorFlow
# ...                                         ...
# 87298                                       NaN
# 87508                                   Node.js
# 88137                  Hadoop;Pandas;TensorFlow
# 88364                                       NaN
# 88672                                       NaN
#
#                                  MiscTechDesireNextYear  \
# Respondent
# 511                                Node.js;React Native
# 1599        .NET;.NET Core;Node.js;React Native;Xamarin
# 1715                     Apache Spark;.NET Core;Node.js
# 2142                                                NaN
# 2434                    Pandas;TensorFlow;Torch/PyTorch
# ...                                                 ...
# 87298                                               NaN
# 87508                                  Node.js;Unity 3D
# 88137                  Hadoop;Node.js;Pandas;TensorFlow
# 88364                   Pandas;TensorFlow;Torch/PyTorch
# 88672                           Apache Spark;TensorFlow
#
#                                                    DevEnviron        OpSys  \
# Respondent
# 511                                         Atom;Sublime Text        MacOS
# 1599        Android Studio;Eclipse;Visual Studio;Visual St...      Windows
# 1715                                       Emacs;IntelliJ;Vim        MacOS
# 2142                                                 IntelliJ  Linux-based
# 2434                                              PyCharm;Vim  Linux-based
# ...                                                       ...          ...
# 87298                                      Visual Studio Code  Linux-based
# 87508                                      Visual Studio Code        MacOS
# 88137       IntelliJ;IPython / Jupyter;PHPStorm;RubyMine;V...        MacOS
# 88364                          IPython / Jupyter;Sublime Text        MacOS
# 88672                                               Vim;Xcode          NaN
#
#                                                    Containers  \
# Respondent
# 511                                   I do not use containers
# 1599                                                  Testing
# 1715                           Development;Testing;Production
# 2142                                       Testing;Production
# 2434                           Development;Testing;Production
# ...                                                       ...
# 87298       Development;Testing;Outside of work, for perso...
# 87508                                 I do not use containers
# 88137                                             Development
# 88364                                              Production
# 88672                                     Development;Testing
#
#                                       BlockchainOrg  \
# Respondent
# 511                                             NaN
# 1599                                     Not at all
# 1715                                            NaN
# 2142                                            NaN
# 2434                                            NaN
# ...                                             ...
# 87298       Non-currency applications of blockchain
# 87508                                    Not at all
# 88137                                    Not at all
# 88364                                    Not at all
# 88672       Non-currency applications of blockchain
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 511                                             A passing fad        Yes
# 1599        Useful for immutable record keeping outside of...        Yes
# 1715                        An irresponsible use of resources        Yes
# 2142                                                      NaN        Yes
# 2434        Useful for immutable record keeping outside of...         No
# ...                                                       ...        ...
# 87298       Useful across many domains and could change ma...        Yes
# 87508       Useful for immutable record keeping outside of...        Yes
# 88137       Useful across many domains and could change ma...        Yes
# 88364                                           A passing fad         No
# 88672                                                     NaN         No
#
#             ITperson  OffOn               SocialMedia  \
# Respondent
# 511              Yes    Yes                  Facebook
# 1599             Yes  What?                   YouTube
# 1715            SIGH    Yes                   Twitter
# 2142             Yes    Yes                    Reddit
# 2434        Also Yes    Yes  I don't use social media
# ...              ...    ...                       ...
# 87298            Yes    Yes                  LinkedIn
# 87508            Yes    Yes                    Reddit
# 88137            Yes    Yes                  Facebook
# 88364            Yes    Yes                   YouTube
# 88672            Yes    Yes                   YouTube
#
#                         Extraversion ScreenName        SOVisit1st  \
# Respondent
# 511                           Online   Username              2008
# 1599        In real life (in person)   Username              2013
# 1715        In real life (in person)   Username              2008
# 2142        In real life (in person)   Username              2010
# 2434        In real life (in person)   Username              2010
# ...                              ...        ...               ...
# 87298                         Online   Username              2010
# 87508                        Neither      Login              2009
# 88137                         Online      Login              2008
# 88364       In real life (in person)   Username  I don't remember
# 88672       In real life (in person)      Login              2008
#
#                                 SOVisitFreq  \
# Respondent
# 511                   Daily or almost daily
# 1599                 Multiple times per day
# 1715                   A few times per week
# 2142                   A few times per week
# 2434                  Daily or almost daily
# ...                                     ...
# 87298       A few times per month or weekly
# 87508                  A few times per week
# 88137                 Daily or almost daily
# 88364                  A few times per week
# 88672                 Daily or almost daily
#
#                                                     SOVisitTo  \
# Respondent
# 511         Find answers to specific questions;Contribute ...
# 1599        Find answers to specific questions;Learn how t...
# 1715        Find answers to specific questions;Learn how t...
# 2142                       Find answers to specific questions
# 2434                       Find answers to specific questions
# ...                                                       ...
# 87298       Find answers to specific questions;Learn how t...
# 87508       Find answers to specific questions;Contribute ...
# 88137       Find answers to specific questions;Contribute ...
# 88364       Find answers to specific questions;Learn how t...
# 88672       Find answers to specific questions;Contribute ...
#
#                            SOFindAnswer                         SOTimeSaved  \
# Respondent
# 511                  1-2 times per week      Stack Overflow was much faster
# 1599                6-10 times per week      Stack Overflow was much faster
# 1715                 3-5 times per week  Stack Overflow was slightly faster
# 2142                 1-2 times per week  Stack Overflow was slightly faster
# 2434        More than 10 times per week  Stack Overflow was slightly faster
# ...                                 ...                                 ...
# 87298                1-2 times per week            They were about the same
# 87508                3-5 times per week  Stack Overflow was slightly faster
# 88137                1-2 times per week      Stack Overflow was much faster
# 88364                3-5 times per week      Stack Overflow was much faster
# 88672           Less than once per week            They were about the same
#
#             SOHowMuchTime SOAccount                           SOPartFreq  \
# Respondent
# 511         11-30 minutes       Yes  Less than once per month or monthly
# 1599          60+ minutes        No                                  NaN
# 1715        11-30 minutes       Yes  Less than once per month or monthly
# 2142         0-10 minutes       Yes  Less than once per month or monthly
# 2434        31-60 minutes        No                                  NaN
# ...                   ...       ...                                  ...
# 87298                 NaN       Yes  Less than once per month or monthly
# 87508       11-30 minutes       Yes      A few times per month or weekly
# 88137         60+ minutes       Yes                 A few times per week
# 88364        0-10 minutes       Yes      A few times per month or weekly
# 88672                 NaN       Yes  Less than once per month or monthly
#
#                                                        SOJobs  \
# Respondent
# 511                                                       Yes
# 1599        No, I didn't know that Stack Overflow had a jo...
# 1715                                                      Yes
# 2142        No, I knew that Stack Overflow had a job board...
# 2434        No, I didn't know that Stack Overflow had a jo...
# ...                                                       ...
# 87298       No, I knew that Stack Overflow had a job board...
# 87508       No, I knew that Stack Overflow had a job board...
# 88137                                                     Yes
# 88364                                                     Yes
# 88672                                                     Yes
#
#                                                      EntTeams  \
# Respondent
# 511                       No, and I don't know what those are
# 1599                      No, and I don't know what those are
# 1715        No, I've heard of them, but I am not part of a...
# 2142        No, I've heard of them, but I am not part of a...
# 2434                      No, and I don't know what those are
# ...                                                       ...
# 87298       No, I've heard of them, but I am not part of a...
# 87508                     No, and I don't know what those are
# 88137       No, I've heard of them, but I am not part of a...
# 88364       No, I've heard of them, but I am not part of a...
# 88672       No, I've heard of them, but I am not part of a...
#
#                      SOComm                             WelcomeChange  \
# Respondent
# 511           Yes, somewhat   Just as welcome now as I felt last year
# 1599                Neutral   Just as welcome now as I felt last year
# 1715          Yes, somewhat   Just as welcome now as I felt last year
# 2142         No, not really                                       NaN
# 2434         No, not really   Just as welcome now as I felt last year
# ...                     ...                                       ...
# 87298         Yes, somewhat  Somewhat less welcome now than last year
# 87508       Yes, definitely   Just as welcome now as I felt last year
# 88137         Yes, somewhat   Just as welcome now as I felt last year
# 88364        No, not really   Just as welcome now as I felt last year
# 88672        No, not really   Just as welcome now as I felt last year
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 511                                                       NaN  33.0    Man
# 1599        Tech articles written by other developers;Indu...  63.0    Man
# 1715                      Tech meetups or events in your area  38.0    Man
# 2142                                                      NaN  28.0    Man
# 2434                                                      NaN  48.0    Man
# ...                                                       ...   ...    ...
# 87298                                                     NaN  50.0    Man
# 87508       Tech articles written by other developers;Indu...  42.0    Man
# 88137                                                     NaN  46.0    Man
# 88364       Tech meetups or events in your area;Courses on...  25.0    Man
# 88672       Tech articles written by other developers;Indu...  56.0    Man
#
#            Trans                Sexuality  \
# Respondent
# 511           No  Straight / Heterosexual
# 1599          No  Straight / Heterosexual
# 1715          No  Straight / Heterosexual
# 2142          No  Straight / Heterosexual
# 2434          No  Straight / Heterosexual
# ...          ...                      ...
# 87298         No           Gay or Lesbian
# 87508         No                 Bisexual
# 88137         No  Straight / Heterosexual
# 88364         No  Straight / Heterosexual
# 88672         No  Straight / Heterosexual
#
#                                                     Ethnicity Dependents  \
# Respondent
# 511                                                East Asian         No
# 1599                             White or of European descent        Yes
# 1715                             White or of European descent        Yes
# 2142                             White or of European descent         No
# 2434                             White or of European descent        Yes
# ...                                                       ...        ...
# 87298                            White or of European descent         No
# 87508       Middle Eastern;Native American, Pacific Island...        Yes
# 88137                            White or of European descent        Yes
# 88364                            White or of European descent         No
# 88672                            White or of European descent        Yes
#
#                      SurveyLength                  SurveyEase
# Respondent
# 511         Appropriate in length                        Easy
# 1599        Appropriate in length                        Easy
# 1715        Appropriate in length                        Easy
# 2142        Appropriate in length                        Easy
# 2434        Appropriate in length  Neither easy nor difficult
# ...                           ...                         ...
# 87298       Appropriate in length                        Easy
# 87508                    Too long                        Easy
# 88137                    Too long                   Difficult
# 88364       Appropriate in length                        Easy
# 88672       Appropriate in length                        Easy
#
# [216 rows x 84 columns]
