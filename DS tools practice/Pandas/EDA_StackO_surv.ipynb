# %%
import pandas as pd
import matplotlib.pyplot as plt

df_survey = pd.read_csv('data/survey_results_public.csv',index_col='Respondent')
schema_df = pd.read_csv('data/survey_results_schema.csv',index_col='Column')
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df_survey
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
flt=(df_survey['CompTotal']>150000)&(df_survey['CurrencySymbol']=='USD')&(df_survey['CompTotal']<300000)
# &(df_survey['CompTotal']<500000)&
# df_survey.loc[flt]

# %%
df_survey.loc[flt,['YearsCode','DevType','WorkWeekHrs','Age','CompTotal']]
# Out:
#            YearsCode                                            DevType  \
# Respondent
# 39                30  Database administrator;Developer, back-end;Dev...
# 45                40                                Engineering manager
# 47                35                                Engineering manager
# 106               20                              Developer, full-stack
# 142                8                                Developer, back-end
# ...              ...                                                ...
# 88794             21  Database administrator;Developer, back-end;Dev...
# 88835             26          Developer, back-end;Developer, full-stack
# 88874              7  Data scientist or machine learning specialist;...
# 88876              8    Developer, back-end;Developer, game or graphics
# 88877             31  Data scientist or machine learning specialist;...
#
#             WorkWeekHrs   Age  CompTotal
# Respondent
# ...

# %%
salary_data=df_survey.dropna(axis=0)
salary_data=salary_data[flt]
# salary_data_graph=salary_data.loc[(salary_data['CompTotal']>300000)].loc[(salary_data['CurrencySymbol']=='USD')].loc[(salary_data['CompTotal']<500000),'CompTotal']
salary_data.set_index('YearsCodePro',inplace=True)
salary_data.sort_index(inplace=True)
plt.plot(salary_data['CompTotal'])
plt.show()
# Out:
# C:\Users\Mi\AppData\Local\Temp\ipykernel_3488\747899943.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   salary_data=salary_data[flt]

# %%
salary_data
# Out:
#                                                      MainBranch Hobbyist  \
# YearsCodePro
# 10                               I am a developer by profession      Yes
# 10                               I am a developer by profession      Yes
# 10                               I am a developer by profession      Yes
# 10                               I am a developer by profession      Yes
# 10            I am not primarily a developer, but I write co...      Yes
# ...                                                         ...      ...
# 8             I am not primarily a developer, but I write co...      Yes
# 8                                I am a developer by profession      Yes
# 9                                I am a developer by profession      Yes
# 9                                I am a developer by profession      Yes
# 9                                I am a developer by profession      Yes
#
#                                                     OpenSourcer  \
# ...

# %%
salary_data=df_survey.dropna(axis=0)
salary_data=salary_data[flt]
salary_data
# Out:
# C:\Users\Mi\AppData\Local\Temp\ipykernel_3488\1174861175.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   salary_data=salary_data[flt]
#                                                    MainBranch Hobbyist  \
# Respondent
# 39                             I am a developer by profession      Yes
# 1843                           I am a developer by profession      Yes
# 1903                           I am a developer by profession      Yes
# 1938                           I am a developer by profession      Yes
# 3159                           I am a developer by profession      Yes
# ...                                                       ...      ...
# 85165                          I am a developer by profession      Yes
# 85479                          I am a developer by profession      Yes
# 87290                          I am a developer by profession      Yes
# 87311       I am not primarily a developer, but I write co...      Yes
# ...

# %%
salary_data_graph=salary_data.loc[(salary_data['CompTotal']>300000)]
salary_data_graph=salary_data_graph.loc[(salary_data_graph['CurrencySymbol']=='USD')]
salary_data_graph=salary_data_graph.loc[(salary_data_graph['CompTotal']<500000)]
salary_data_graph
# Out:
# Empty DataFrame
# ...

# %%
salary_data_graph=df_survey.loc[(df_survey['CompTotal']>300000)].loc[(df_survey['CurrencySymbol']=='USD')].loc[(df_survey['CompTotal']<500000)]
